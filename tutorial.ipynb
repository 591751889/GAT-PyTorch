# %%
# %run train.py --model gcn --impl pyg --hidden_dim 64 --heads 8
# Out:
# 🖥  Using device: cuda
# Model: GCN
#     params: {'in_dim': 1433, 'hidden_dim': 64, 'out_dim': 7, 'dropout': 0.6}
# Total trainable parameters: 92,231
# Checkpoint path: logs/best_gcn_pyg.pt
#
# [Checkpoint] Epoch 001 | Val 42.40% | Test 43.80%
# [Checkpoint] Epoch 002 | Val 57.00% | Test 58.90%
# [Checkpoint] Epoch 003 | Val 65.60% | Test 70.10%
# [Checkpoint] Epoch 004 | Val 70.80% | Test 74.20%
# [Checkpoint] Epoch 005 | Val 73.80% | Test 75.60%
# [Checkpoint] Epoch 006 | Val 75.40% | Test 77.30%
# [Checkpoint] Epoch 007 | Val 77.40% | Test 78.50%
# [Checkpoint] Epoch 008 | Val 77.60% | Test 79.10%
# [Checkpoint] Epoch 009 | Val 78.20% | Test 79.80%
# [Checkpoint] Epoch 010 | Val 78.40% | Test 80.40%
# Epoch 010 | Loss 0.9294 | Train 97.86% | Val 78.40% | Test 80.40% | Time 6.5 ms
# [Checkpoint] Epoch 011 | Val 78.60% | Test 80.70%
# [Checkpoint] Epoch 014 | Val 78.80% | Test 81.20%
# [Checkpoint] Epoch 015 | Val 79.00% | Test 80.80%
# ...

# %%
# %run train.py --model gat --impl pyg --hidden_dim 64 --heads 8
# Out:
# 🖥  Using device: cuda
# Model: GAT
#     params: {'in_dim': 1433, 'hidden_dim': 64, 'out_dim': 7, 'heads': 8, 'dropout': 0.6}
# Total trainable parameters: 738,837
# Checkpoint path: logs/best_gat_pyg.pt
#
# [Checkpoint] Epoch 001 | Val 42.60% | Test 46.70%
# [Checkpoint] Epoch 002 | Val 64.60% | Test 67.30%
# [Checkpoint] Epoch 003 | Val 72.00% | Test 76.20%
# [Checkpoint] Epoch 004 | Val 74.60% | Test 77.80%
# [Checkpoint] Epoch 005 | Val 76.60% | Test 79.80%
# [Checkpoint] Epoch 006 | Val 78.00% | Test 80.40%
# [Checkpoint] Epoch 007 | Val 78.40% | Test 80.50%
# [Checkpoint] Epoch 008 | Val 79.20% | Test 81.20%
# [Checkpoint] Epoch 009 | Val 79.40% | Test 81.40%
# Epoch 010 | Loss 0.8483 | Train 96.43% | Val 79.00% | Test 81.30% | Time 9.2 ms
# [Checkpoint] Epoch 018 | Val 79.80% | Test 82.40%
# [Checkpoint] Epoch 019 | Val 80.40% | Test 82.10%
# Epoch 020 | Loss 0.5850 | Train 99.29% | Val 80.40% | Test 82.30% | Time 8.9 ms
# ...

# %%
# %run train.py --model gin --impl pyg --hidden_dim 64 --heads 8
# Out:
# 🖥  Using device: cuda
# Model: GIN
#     params: {'in_dim': 1433, 'hidden_dim': 64, 'out_dim': 7, 'dropout': 0.6}
# Total trainable parameters: 104,969
# Checkpoint path: logs/best_gin_pyg.pt
#
# [Checkpoint] Epoch 001 | Val 20.60% | Test 20.80%
# [Checkpoint] Epoch 002 | Val 24.60% | Test 24.30%
# [Checkpoint] Epoch 005 | Val 25.60% | Test 24.20%
# [Checkpoint] Epoch 006 | Val 27.80% | Test 26.90%
# [Checkpoint] Epoch 007 | Val 32.20% | Test 30.10%
# [Checkpoint] Epoch 008 | Val 34.60% | Test 33.70%
# [Checkpoint] Epoch 009 | Val 38.60% | Test 37.10%
# [Checkpoint] Epoch 010 | Val 42.60% | Test 41.30%
# Epoch 010 | Loss 1.4449 | Train 62.14% | Val 42.60% | Test 41.30% | Time 7.3 ms
# [Checkpoint] Epoch 011 | Val 44.80% | Test 43.00%
# [Checkpoint] Epoch 012 | Val 45.40% | Test 44.40%
# [Checkpoint] Epoch 013 | Val 46.80% | Test 46.40%
# [Checkpoint] Epoch 014 | Val 47.20% | Test 48.50%
# [Checkpoint] Epoch 015 | Val 49.80% | Test 52.10%
# ...

# %%
# %run train.py --model gcn --impl no_pyg --hidden_dim 64 --heads 8
# Out:
# 🖥  Using device: cuda
# Model: GCN
#     params: {'in_dim': 1433, 'hidden_dim': 64, 'out_dim': 7, 'dropout': 0.6}
# Total trainable parameters: 92,231
# Checkpoint path: logs/best_gcn_no_pyg.pt
#
# [Checkpoint] Epoch 001 | Val 42.00% | Test 42.50%
# [Checkpoint] Epoch 002 | Val 55.40% | Test 59.40%
# [Checkpoint] Epoch 003 | Val 59.40% | Test 63.90%
# [Checkpoint] Epoch 004 | Val 64.20% | Test 68.20%
# [Checkpoint] Epoch 005 | Val 67.60% | Test 69.80%
# [Checkpoint] Epoch 006 | Val 69.40% | Test 72.00%
# [Checkpoint] Epoch 007 | Val 70.60% | Test 73.50%
# [Checkpoint] Epoch 008 | Val 72.20% | Test 75.10%
# [Checkpoint] Epoch 009 | Val 74.80% | Test 76.40%
# [Checkpoint] Epoch 010 | Val 75.40% | Test 77.60%
# Epoch 010 | Loss 1.3009 | Train 94.29% | Val 75.40% | Test 77.60% | Time 6.0 ms
# [Checkpoint] Epoch 011 | Val 77.40% | Test 77.90%
# [Checkpoint] Epoch 012 | Val 78.20% | Test 79.30%
# [Checkpoint] Epoch 013 | Val 78.40% | Test 79.70%
# ...

# %%
# %run train.py --model gat --impl no_pyg --hidden_dim 64 --heads 8
# Out:
# 🖥  Using device: cuda
# Model: GAT
#     params: {'in_dim': 1433, 'hidden_dim': 64, 'out_dim': 7, 'heads': 8, 'dropout': 0.6}
# Total trainable parameters: 738,837
# Checkpoint path: logs/best_gat_no_pyg.pt
#
# [Checkpoint] Epoch 001 | Val 42.00% | Test 42.70%
# [Checkpoint] Epoch 002 | Val 56.40% | Test 58.00%
# [Checkpoint] Epoch 003 | Val 67.20% | Test 67.80%
# [Checkpoint] Epoch 004 | Val 70.00% | Test 70.60%
# [Checkpoint] Epoch 005 | Val 71.80% | Test 73.20%
# [Checkpoint] Epoch 006 | Val 73.20% | Test 74.60%
# [Checkpoint] Epoch 007 | Val 74.40% | Test 75.90%
# [Checkpoint] Epoch 008 | Val 74.60% | Test 76.70%
# [Checkpoint] Epoch 009 | Val 75.40% | Test 76.90%
# [Checkpoint] Epoch 010 | Val 77.00% | Test 78.50%
# Epoch 010 | Loss 0.9643 | Train 94.29% | Val 77.00% | Test 78.50% | Time 11.1 ms
# [Checkpoint] Epoch 011 | Val 78.00% | Test 80.00%
# [Checkpoint] Epoch 012 | Val 78.60% | Test 80.40%
# [Checkpoint] Epoch 015 | Val 79.20% | Test 80.80%
# ...

# %%
# %run train.py --model gin --impl no_pyg --hidden_dim 64 --heads 8
# Out:
# 🖥  Using device: cuda
# Model: GIN
#     params: {'in_dim': 1433, 'hidden_dim': 64, 'out_dim': 7, 'dropout': 0.6}
# Total trainable parameters: 105,039
# Checkpoint path: logs/best_gin_no_pyg.pt
#
# [Checkpoint] Epoch 001 | Val 17.00% | Test 16.10%
# [Checkpoint] Epoch 003 | Val 24.60% | Test 25.20%
# [Checkpoint] Epoch 005 | Val 26.60% | Test 26.00%
# [Checkpoint] Epoch 006 | Val 31.00% | Test 30.40%
# [Checkpoint] Epoch 007 | Val 35.00% | Test 34.90%
# [Checkpoint] Epoch 008 | Val 38.80% | Test 37.00%
# [Checkpoint] Epoch 010 | Val 39.40% | Test 37.10%
# Epoch 010 | Loss 1.6796 | Train 45.00% | Val 39.40% | Test 37.10% | Time 5.0 ms
# [Checkpoint] Epoch 011 | Val 40.20% | Test 37.20%
# [Checkpoint] Epoch 013 | Val 41.60% | Test 37.60%
# [Checkpoint] Epoch 017 | Val 42.60% | Test 39.70%
# [Checkpoint] Epoch 018 | Val 42.80% | Test 41.00%
# Epoch 020 | Loss 1.4492 | Train 56.43% | Val 42.00% | Test 41.20% | Time 5.0 ms
# ...
